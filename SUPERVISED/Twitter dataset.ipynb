# %%
import pandas as pd

# %%
df=pd.read_csv("D:\\Predictive Analysis\\Data Sets\\twitter.csv")
df
# Out:
#      id               candidate  candidate_confidence relevant_yn  \
# 0     1  No candidate mentioned                1.0000         yes
# 1     2            Scott Walker                1.0000         yes
# 2     3  No candidate mentioned                1.0000         yes
# 3     4  No candidate mentioned                1.0000         yes
# 4     5            Donald Trump                1.0000         yes
# ..  ...                     ...                   ...         ...
# 95   96            Donald Trump                1.0000         yes
# 96   97                Jeb Bush                0.4413         yes
# 97   98  No candidate mentioned                1.0000         yes
# 98   99             Marco Rubio                0.4535         yes
# 99  100            Donald Trump                1.0000         yes
#
#     relevant_yn_confidence sentiment  sentiment_confidence     subject_matter  \
# 0                   1.0000   Neutral                0.6578  None of the above
# ...

# %%
df.isnull().sum()
# Out:
# id                             0
# candidate                      1
# candidate_confidence           0
# relevant_yn                    0
# relevant_yn_confidence         0
# sentiment                      0
# sentiment_confidence           0
# subject_matter                 2
# subject_matter_confidence      0
# candidate_gold               100
# name                           0
# relevant_yn_gold             100
# retweet_count                  0
# sentiment_gold               100
# subject_matter_gold          100
# text                           0
# tweet_coord                  100
# tweet_created                  0
# tweet_id                       0
# tweet_location                36
# user_timezone                 30
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         100 non-null    int64
#  1   candidate                  99 non-null     object
#  2   candidate_confidence       100 non-null    float64
#  3   relevant_yn                100 non-null    object
#  4   relevant_yn_confidence     100 non-null    float64
#  5   sentiment                  100 non-null    object
#  6   sentiment_confidence       100 non-null    float64
#  7   subject_matter             98 non-null     object
#  8   subject_matter_confidence  100 non-null    float64
#  9   candidate_gold             0 non-null      float64
#  10  name                       100 non-null    object
#  11  relevant_yn_gold           0 non-null      float64
#  12  retweet_count              100 non-null    int64
# ...

# %%
df.dtypes
# Out:
# id                             int64
# candidate                     object
# candidate_confidence         float64
# relevant_yn                   object
# relevant_yn_confidence       float64
# sentiment                     object
# sentiment_confidence         float64
# subject_matter                object
# subject_matter_confidence    float64
# candidate_gold               float64
# name                          object
# relevant_yn_gold             float64
# retweet_count                  int64
# sentiment_gold               float64
# subject_matter_gold          float64
# text                          object
# tweet_coord                  float64
# tweet_created                 object
# tweet_id                     float64
# tweet_location                object
# user_timezone                 object
# dtype: object

# %%
df['subject_matter'].unique()
df['tweet_location'].unique()
# Out:
# array([nan, 'Texas', 'North Georgia', 'New York NY', 'Peoria, IL',
#        'Fargo, ND', 'Montgomery, AL ', 'San Diego, California', 'NJ',
#        'fripp island,sc/ southeast ga', 'Conspiracy Theoryland',
#        'Lynnwood, WA', 'Vancouver, Canada', 'Sydney, New South Wales',
#        'USA ', 'Cleveland Texas', 'EveryWhere', 'Green Bay, WI',
#        'European Union', 'Canada', 'News about tech and more!',
#        'United States of America', 'Arizona', 'Chicago, IL', 'Tac',
#        'Washington, DC', 'California', 'Richmond, VA', 'Fort Worth',
#        'U.S. city with the most Cubans', 'Denver, CO', 'Los Angeles',
#        'Houston, TX', 'Midgard', 'U.S.A', 'Rhinebeck, NY', 'NW Florida',
#        'Delaware', 'Florida,, usually', ' NYC', 'San Diego',
#        'Seattle, WA', 'Oxnerd, California', 'Vatican City',
#        'Pittsburgh, PA', 'TEXAS is the greatest state',
#        'Illinois, SW of Chicago', 'Walland, Tn', 'Holland, Michigan USA ',
# ...

# %%
df['candidate']=df['candidate'].bfill()
df['subject_matter']=df['subject_matter'].ffill()
df['tweet_location']=df['tweet_location'].bfill()
df['user_timezone']=df['user_timezone'].ffill()

# %%
df.isnull().sum()
# Out:
# id                             0
# candidate                      0
# candidate_confidence           0
# relevant_yn                    0
# relevant_yn_confidence         0
# sentiment                      0
# sentiment_confidence           0
# subject_matter                 0
# subject_matter_confidence      0
# candidate_gold               100
# name                           0
# relevant_yn_gold             100
# retweet_count                  0
# sentiment_gold               100
# subject_matter_gold          100
# text                           0
# tweet_coord                  100
# tweet_created                  0
# tweet_id                       0
# tweet_location                 0
# user_timezone                  0
# dtype: int64

# %%
df = df.drop(['candidate_gold','relevant_yn_gold','sentiment_gold','subject_matter_gold','tweet_coord'],axis=1)

# %%
df
# Out:
#      id               candidate  candidate_confidence relevant_yn  \
# 0     1  No candidate mentioned                1.0000         yes
# 1     2            Scott Walker                1.0000         yes
# 2     3  No candidate mentioned                1.0000         yes
# 3     4  No candidate mentioned                1.0000         yes
# 4     5            Donald Trump                1.0000         yes
# ..  ...                     ...                   ...         ...
# 95   96            Donald Trump                1.0000         yes
# 96   97                Jeb Bush                0.4413         yes
# 97   98  No candidate mentioned                1.0000         yes
# 98   99             Marco Rubio                0.4535         yes
# 99  100            Donald Trump                1.0000         yes
#
#     relevant_yn_confidence sentiment  sentiment_confidence     subject_matter  \
# 0                   1.0000   Neutral                0.6578  None of the above
# ...

# %%
df.isnull().sum()
# Out:
# id                           0
# candidate                    0
# candidate_confidence         0
# relevant_yn                  0
# relevant_yn_confidence       0
# sentiment                    0
# sentiment_confidence         0
# subject_matter               0
# subject_matter_confidence    0
# name                         0
# retweet_count                0
# text                         0
# tweet_created                0
# tweet_id                     0
# tweet_location               0
# user_timezone                0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['relevant_yn']=le.fit_transform(df['relevant_yn'])

# %%
df
# Out:
#      id               candidate  candidate_confidence  relevant_yn  \
# 0     1  No candidate mentioned                1.0000            0
# 1     2            Scott Walker                1.0000            0
# 2     3  No candidate mentioned                1.0000            0
# 3     4  No candidate mentioned                1.0000            0
# 4     5            Donald Trump                1.0000            0
# ..  ...                     ...                   ...          ...
# 95   96            Donald Trump                1.0000            0
# 96   97                Jeb Bush                0.4413            0
# 97   98  No candidate mentioned                1.0000            0
# 98   99             Marco Rubio                0.4535            0
# 99  100            Donald Trump                1.0000            0
#
#     relevant_yn_confidence sentiment  sentiment_confidence     subject_matter  \
# 0                   1.0000   Neutral                0.6578  None of the above
# ...

# %%
df['sentiment'].unique()
# Out:
# array(['Neutral', 'Positive', 'Negative'], dtype=object)
